# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_pop=pd.read_csv('ProvincePopulation.csv') ##importing the two dataset##
data_crime=pd.read_csv('SouthAfricaCrimeStats_v2.csv')

# %%
data_pop.head()
# Out:
#         Province  Population    Area  Density
# 0        Gauteng    12272263   18178    675.1
# 1  Kwazulu/Natal    10267300   94361    108.8
# 2     Mpumalanga     4039939   76495     52.8
# 3   Western Cape     5822734  129462     45.0
# 4        Limpopo     5404868  125755     43.0

# %% [markdown]
# ## QUESTION 1 ##

# %%
data_crime.head()
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
data_merge=pd.merge(data_pop,data_crime, on ='Province') ##merging the two dataset as one##

# %%
data_merge.head()
# Out:
#   Province  Population   Area  Density           Station  \
# 0  Gauteng    12272263  18178    675.1       Jhb Central
# 1  Gauteng    12272263  18178    675.1  Pretoria Central
# 2  Gauteng    12272263  18178    675.1          Brooklyn
# 3  Gauteng    12272263  18178    675.1          Booysens
# 4  Gauteng    12272263  18178    675.1          Hillbrow
#
#                             Category  2005-2006  2006-2007  2007-2008  \
# 0  All theft not mentioned elsewhere       6093       4602       3761
# 1  All theft not mentioned elsewhere       5099       4536       3309
# 2  All theft not mentioned elsewhere       3931       3583       2878
# 3  All theft not mentioned elsewhere       3681       3277       2849
# 4  All theft not mentioned elsewhere       3489       2914       3093
#
#    2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# 0       3610       3267       3037       2886       2638       2809
# ...

# %%
 dm=data_merge.groupby('Province')###grouping based on Provinces### 
dm

# %%
for Province, Province_data_merge in dm:  ##printing the Province in the dataset##
    print(Province)
    print(Province_data_merge)
# Out:
# Eastern Cape
#            Province  Population    Area  Density                 Station  \
# 17928  Eastern Cape     6562053  168966     38.8             East London
# 17929  Eastern Cape     6562053  168966     38.8                Humewood
# 17930  Eastern Cape     6562053  168966     38.8              Mount Road
# 17931  Eastern Cape     6562053  168966     38.8               Cambridge
# 17932  Eastern Cape     6562053  168966     38.8                  Walmer
# 17933  Eastern Cape     6562053  168966     38.8             Grahamstown
# 17934  Eastern Cape     6562053  168966     38.8             Bethelsdorp
# 17935  Eastern Cape     6562053  168966     38.8                Humewood
# 17936  Eastern Cape     6562053  168966     38.8                Humewood
# 17937  Eastern Cape     6562053  168966     38.8                 Mthatha
# 17938  Eastern Cape     6562053  168966     38.8              Gelvandale
# 17939  Eastern Cape     6562053  168966     38.8               Kwazakele
# ...

# %%
dm.sum()
# Out:
#                 Population       Area    Density  2005-2006  2006-2007  \
# Province
# Eastern Cape   34726384476  894168072   205329.6     238977     228884
# Free State      8154402300  385580250    62667.0     137987     128227
# Gauteng        47383207443   70185258  2606561.1     654817     639635
# Kwazulu/Natal  51562380600  473880942   546393.6     345784     343798
# Limpopo        14447212164  336143115   114939.0     106983     104857
# Mpumalanga      9380738358  177621390   122601.6     134829     131444
# North West      7771035942  232208748    74169.0     118840     112471
# Northern Cape   2815380477  916188273     7616.7      56515      52689
# Western Cape   23582072700  524321100   182250.0     381825     396712
#
#                2007-2008  2008-2009  2009-2010  2010-2011  2011-2012  \
# Province
# Eastern Cape      220813     216658     217230     215012     214462
# Free State        127955     132335     127512     121997     126389
# ...

# %%
dm.max()
# Out:
#                Population    Area  Density      Station         Category  \
# Province
# Eastern Cape      6562053  168966     38.8    Zwelitsha  Truck hijacking
# Free State        2745590  129825     21.1      Zastron  Truck hijacking
# Gauteng          12272263   18178    675.1   Zonkizizwe  Truck hijacking
# Kwazulu/Natal    10267300   94361    108.8    Winterton  Truck hijacking
# Limpopo           5404868  125755     43.0    Zebediela  Truck hijacking
# Mpumalanga        4039939   76495     52.8    Witrivier  Truck hijacking
# North West        3509953  104882     33.5      Zeerust  Truck hijacking
# Northern Cape     1145861  372889      3.1  Wrenchville  Truck hijacking
# Western Cape      5822734  129462     45.0      Wynberg  Truck hijacking
#
#                2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  \
# Province
# Eastern Cape        2892       2432       2288       2104       1657
# Free State          5108       4282       3834       3316       3101
# ...

# %%
dm.describe()
# Out:
#               Population                                                       \
#                    count        mean  std         min         25%         50%
# Province
# Eastern Cape      5292.0   6562053.0  0.0   6562053.0   6562053.0   6562053.0
# Free State        2970.0   2745590.0  0.0   2745590.0   2745590.0   2745590.0
# Gauteng           3861.0  12272263.0  0.0  12272263.0  12272263.0  12272263.0
# Kwazulu/Natal     5022.0  10267300.0  0.0  10267300.0  10267300.0  10267300.0
# Limpopo           2673.0   5404868.0  0.0   5404868.0   5404868.0   5404868.0
# Mpumalanga        2322.0   4039939.0  0.0   4039939.0   4039939.0   4039939.0
# North West        2214.0   3509953.0  0.0   3509953.0   3509953.0   3509953.0
# Northern Cape     2457.0   1145861.0  0.0   1145861.0   1145861.0   1145861.0
# Western Cape      4050.0   5822734.0  0.0   5822734.0   5822734.0   5822734.0
#
#                                          Area            ... 2014-2015  \
# ...

# %%
dm.mean()
# Out:
#                Population      Area  Density   2005-2006   2006-2007  \
# Province
# Eastern Cape    6562053.0  168966.0     38.8   45.158163   43.250945
# Free State      2745590.0  129825.0     21.1   46.460269   43.174074
# Gauteng        12272263.0   18178.0    675.1  169.597773  165.665631
# Kwazulu/Natal  10267300.0   94361.0    108.8   68.853843   68.458383
# Limpopo         5404868.0  125755.0     43.0   40.023569   39.228208
# Mpumalanga      4039939.0   76495.0     52.8   58.065891   56.608096
# North West      3509953.0  104882.0     33.5   53.676603   50.799910
# Northern Cape   1145861.0  372889.0      3.1   23.001628   21.444444
# Western Cape    5822734.0  129462.0     45.0   94.277778   97.953580
#
#                 2007-2008   2008-2009   2009-2010   2010-2011   2011-2012  \
# Province
# Eastern Cape    41.725813   40.940665   41.048753   40.629630   40.525699
# Free State      43.082492   44.557239   42.933333   41.076431   42.555219
# ...

# %% [markdown]
# ## QUESTION 3 ##

# %%
 dm1=data_merge.groupby('Category')###grouping based on Crime### 
dm1.describe()
# Out:
#                                                    Population                \
#                                                         count          mean
# Category
# All theft not mentioned elsewhere                      1143.0  6.474930e+06
# Arson                                                  1143.0  6.474930e+06
# Assault with the intent to inflict grievous bod...     1143.0  6.474930e+06
# Attempted murder                                       1143.0  6.474930e+06
# Bank robbery                                           1143.0  6.474930e+06
# Burglary at non-residential premises                   1143.0  6.474930e+06
# Burglary at residential premises                       1143.0  6.474930e+06
# Carjacking                                             1143.0  6.474930e+06
# Commercial crime                                       1143.0  6.474930e+06
# Common assault                                         1143.0  6.474930e+06
# ...

# %%
dm1.mean()
# Out:
#                                                       Population  \
# Category
# All theft not mentioned elsewhere                   6.474930e+06
# Arson                                               6.474930e+06
# Assault with the intent to inflict grievous bod...  6.474930e+06
# Attempted murder                                    6.474930e+06
# Bank robbery                                        6.474930e+06
# Burglary at non-residential premises                6.474930e+06
# Burglary at residential premises                    6.474930e+06
# Carjacking                                          6.474930e+06
# Commercial crime                                    6.474930e+06
# Common assault                                      6.474930e+06
# Common robbery                                      6.474930e+06
# Driving under the influence of alcohol or drugs     6.474930e+06
# Drug-related crime                                  6.474930e+06
# ...

# %%
dm1.max()
# Out:
#                                                         Province  Population  \
# Category
# All theft not mentioned elsewhere                   Western Cape    12272263
# Arson                                               Western Cape    12272263
# Assault with the intent to inflict grievous bod...  Western Cape    12272263
# Attempted murder                                    Western Cape    12272263
# Bank robbery                                        Western Cape    12272263
# Burglary at non-residential premises                Western Cape    12272263
# Burglary at residential premises                    Western Cape    12272263
# Carjacking                                          Western Cape    12272263
# Commercial crime                                    Western Cape    12272263
# Common assault                                      Western Cape    12272263
# Common robbery                                      Western Cape    12272263
# ...

# %% [markdown]
# ## QUESTION 4 ##
